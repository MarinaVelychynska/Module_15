# %% [markdown]
# # Salaries with plotly

# %%
import matplotlib.pyplot as plt

# %%
salaries = [("Mark", 1000), ("John", 1500), ("Daniel", 2300), ("Greg", 5000)]
names = ["Mark", "John", "Daniel", "Greg"]
values = [1000, 1500, 2300, 5000]
plt.bar(names, values)
plt.show()
